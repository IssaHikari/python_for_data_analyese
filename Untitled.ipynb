# %%
# from pyodide.http import pyfetch

# import pandas as pd

# filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt"

# async def download(url, filename):

#     response = await pyfetch(url)

#     if response.status == 200:

#         with open(filename, "wb") as f:

#             f.write(await response.bytes())

# await download(filename, "example1.txt")

# print("done")

# %%
with open("example1.txt", "r") as file1:
    FileContent = file1.read()
    print(FileContent)

print(file1.closed)
print(FileContent)
# Out:
# aissa Royce
# aplea vinsinso
# lgang tiflo
# True
# aissa Royce
# aplea vinsinso
# lgang tiflo

# %%
with open("example1.txt", "r") as file1:
    print(file1.read(4))
# Out:
# aiss

# %%
with open("example1.txt", "r") as file1:
    print(file1.read(4))
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# aiss
# a Ro
# yce
# apl
# ea vinsinso
# lga

# %%
with open("example1.txt" , "r") as file1:
    print(file1.read(5))
    print(file1.read(10))
    print(file1.read(15))
# Out:
# aissa
#  Royce
# apl
# ea vinsinso
# lga

# %%
with open("example1.txt" , "r") as file1:
    print("the first line in the file :" , file1.readline())
# Out:
# the first line in the file : aissa Royce

# %%
with open("example1.txt","r") as file1:
        i = 0;
        for line in file1:
            print("Iteration", str(i), ": ", line)
            i = i + 1
# Out:
# Iteration 0 :  aissa Royce
#
# Iteration 1 :  aplea vinsinso
#
# Iteration 2 :  lgang tiflo

# %%
with open("example1.txt","r") as file1:
    ListFile = file1.readlines()
print(ListFile)
# Out:
# ['aissa Royce\n', 'aplea vinsinso\n', 'lgang tiflo']

# %%
with open("example2.txt" , "w") as file2:
    file2.write("This the line A\n")
    file2.write("This the line B\n")
    file2.write("This the line C\n")

# %%
listFile = ["This the line A\n" , "This the line B\n" , "This the line C\n" , "aissa"]
with open("example2.txt" , "w") as file2:
    for item in listFile:
        file2.write(item)

# %%
listFile = ["This the line A\n" , "This the line B\n" , "This the line C\n" , "aissa"]
with open("example2.txt" , "a") as file2:
    for item in listFile:
        file2.write(item)

# %%
with open("example1.txt","r") as file1:
    with open("example3.txt" , "w") as file3:
        for line in file1:
            file3.write(line)

# %%
# Write and Save Files in Python
# the line testwritefile.write("This is line E\n") add the text in the end of file and the line print(testwritefile.read()) don't print anything because the posistion of the cursor in the end of file
with open('example2.txt', 'a+') as testwritefile:
    testwritefile.write("This is line E\n")
    print(testwritefile.read())

# %%
# tell() function return the converte the file in the bianry and return 0 if the cursor in the start of the file
with open("example1.txt", "r") as file:
    print(file.tell())
# Out:
# 0

# %%
# the function seek() file.seek(offset , from_where) change the possition of the cursor if the from_where is equles 0 the cursor chagend to the start it equle to 1 the cursor posstion the cureent posstion if equle to 2 the cursor posstion in the end of the file
with open("example2.txt" , "a+") as testwritefile:
    print("the location {}:" .format(testwritefile.tell()))

    data = testwritefile.read()

    if (not data):
        print("read nating")
    else :
        print(testwritefile.read())

    testwritefile.seek(0,0)

    print("the new location {}:" ,format(testwritefile.tell()))

    data = testwritefile.read()

    if(not data):
        print("Read nating")
    else:
        print(data)

    print("the location after read {}:" .format(testwritefile.tell()))
# Out:
# the location 144:
# read nating
# the new location {}: 0
# This the line A
# This the line B
# This the line C
# aissaThis the line A
# This the line B
# This the line C
# aissaThis is line E
# This is line E
#
# the location after read 144:

# %%
# if not to use truncate()
with open("example2.txt" , "r+") as testreadfile:
    testreadfile.seek(0,0)
    testreadfile.write("aissa\n")
    testreadfile.write("younes\n")
    testreadfile.write("royce\n")
    testreadfile.write("finished\n")
    testreadfile.seek(0,0)
    print(testreadfile.read())
# Out:
# aissa
# younes
# royce
# finished
#
# This the line C
# aissaThis the line A
# This the line B
# This the line C
# aissaThis is line E
# This is line E

# %% [markdown]
# # if not to use truncate()
# with open("example2.txt" , "r+") as testreadfile:
#     testreadfile.seek(0,0)
#     testreadfile.write("aissa\n")
#     testreadfile.write("younes\n")
#     testreadfile.write("royce\n")
#     testreadfile.write("finished\n")
#     testreadfile.truncate()
#     testreadfile.seek(0,0)
#
#     print(testreadfile.read())

# %%
from random import randint as rnd

memReg = 'members.txt'
exReg = 'inactive.txt'

fee = ('yes','no')

def genFile(current , old):
    with open(current , "w+") as writefile:
        writefile.write("Membership No Date Joined Active \n")
        data = "{:^13} {:<11} {:<6}\n"
        
        for rowno in range(20):
            date = str(rnd(2015,2020)) + '-' + str(rnd(1,12)) + '-' + str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999) , date,fee[rnd(0,1)]))
            
    with open(old,"w+") as writefile:
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13} {:<11} {:<6}\n"

        for rowno in  range(3):
            date = str(rnd(2015,2020)) + '-' + str(rnd(1,12)) + '-' + str(rnd(1,25))
            writefile.write(data.format(rnd(10000 , 99999) , date , fee[1]))

genFile(memReg,exReg)


def cleanFiles(currentMem , exMem):
    with open(currentMem , "r+") as currentFile:
        with open(exMem , "a+") as exFile:

            members = currentFile.readlines()

            headers = members[0]

            members = members[1:]

            
            active_membres= []

            for member in members:
                if "no" in member:
                    exFile.write(member)
                else:
                    active_membres.append(member)

            
            currentFile.seek(0)

            currentFile.write(headers)

            for member in active_membres:
                currentFile.write(member)

            currentFile.truncate()

cleanFiles(memReg , exReg)


headers = "Membership No  Date Joined  Active  \n"
with open(memReg,'r') as readFile:
    print("Active Members: \n\n")
    print(readFile.read())
    
with open(exReg,'r') as readFile:
    print("Inactive Members: \n\n")
    print(readFile.read())
# Out:
# Active Members:
#
#
# Membership No Date Joined Active
#     46335     2019-3-17   yes
#     15038     2019-1-9    yes
#     90189     2017-8-4    yes
#     11347     2020-9-2    yes
#     60515     2019-3-10   yes
#     84551     2017-6-16   yes
#
# Inactive Members:
#
#
# Membership No  Date Joined  Active
#     71314     2020-6-7    no
#     11167     2018-7-11   no
#     44996     2019-11-20  no
#     79908     2019-7-18   no
#     35661     2016-8-2    no
#     98019     2019-5-23   no
#     52292     2019-3-15   no
#     53570     2020-3-10   no
#     74761     2020-9-17   no
#     31809     2015-4-13   no
#     10689     2020-8-12   no
#     56571     2017-9-12   no
#     17967     2020-10-22  no
#     48262     2016-7-7    no
#     79279     2017-3-15   no
#     73505     2019-7-11   no
#     60478     2020-7-12   no

# %%
def testMeg(passed):
    if passed:
        return "Test Passed"
    else:
        return "Test Failed"
    testWrite = "testWrite.txt"
    testAppend = "testAppend.txt"
    passed = True

    genFile(testWrite , testAppend)

    with open(testWrite , "r") as file:
        ogWrite = file.readlines()
        
    with open(testAppend , "r") as file:
        ogAppend = file.readlines()

    
    try:
        cleanFiles(testWrite , testAppend)
    except:
        print("Error")

    
    with open(testWrite , "r") as file:
        clWrite = file.readlines()
        
    with open(testAppend , "r") as file:
        clAppend = file.readlines()

# checking if total no of rows is same, including headers

    if (len(ogWrite) + len(ogAppend) != len(clWrite) + len(clAppend)):
    print("The number of rows do not add up. Make sure your final files have the same header and format.")
    passed = False
    
    for line in clWrite:
        if  'no' in line:
            passed = False
            print("Inactive members in file")
            break
        else:
            if line not in ogWrite:
                print("Data in file does not match original file")
                passed = False
    print ("{}".format(testMsg(passed)))
# Out:
#   Cell In[62], line 34
#     print("The number of rows do not add up. Make sure your final files have the same header and format.")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 33
